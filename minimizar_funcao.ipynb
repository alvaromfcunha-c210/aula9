# %% [markdown]
# # Algoritimo genético: minimizar a função x²+y².
#
# ![1](imagens/1.png)

# %% [markdown]
# ### Modelando conjunto binário:

# %%
import numpy as np

class BitSet:
  def __init__(self, size):
    self.bits = np.full((1, size), False)

  def get(self, index):
    return self.bits[0, index]

  def set(self, index, value):
    self.bits[0, index] = value

  def flip(self, index):
    self.bits[0, index] = not self.bits[0, index]

  def debug(self):
    print(self.bits)

# %% [markdown]
# ### Modelando o Cromossomo:
#
# ```
# Genotípo com 10 bits:
#   ##### #####
#     |     |_ valor de y.
#     |_ valor de x.
#
# Para cada variável: 4 bits para valor numérico e 1 bit para sinal (vvvvs).
# Menor bit significativo a esquerda.
# ```

# %%
import random

class Chromossome:
  def __init__(self, x = None, y = None):
    '''
      Estancia o cromossomo com os valores de x e y (caso não sejam atribuidos são gerados valores aleatórios).
    '''
    if x == None:
      x = random.randint(-15, 15)

    if y == None:
      y = random.randint(-15, 15)

    self.__genes = Chromossome.get_genotype(x, y)

  def get_genes(self):
    return self.__genes

  def set_genes(self, genes):
    self.__genes = genes

  def __repr__(self):
    chr_str = "G = ["

    for i in range(10):
      chr_str += (i == 5 and " " or "") + (self.__genes.get(i) and "1" or "0")

    x, y = Chromossome.get_fenotype(self.__genes)

    chr_str += "], F = [" + str(x) + ", " + str(y) + "]"

    return chr_str

  @staticmethod
  def get_genotype(x, y):
    '''
      Método estático que retorna o genótipo dado o valor de x e y.
    '''
    bits = BitSet(10)

    xy_binary = "{:05b}".format(x) + "{:05b}".format(y)

    for i in range(10):
      bits.set(i, xy_binary[i] == '1')

    return bits

  @staticmethod
  def get_fenotype(genes):
    '''
      Método estático que retorna o valor de x e y dado o genótipo.
    '''
    x = (8 * genes.get(0) +
        4 * genes.get(1) +
        2 * genes.get(2) +
        1 * genes.get(3))

    if (genes.get(4) == 1):
        x *= -1

    y = (8 * genes.get(5) +
        4 * genes.get(6) +
        2 * genes.get(7) +
        1 * genes.get(8))

    if (genes.get(9) == 1):
        y *= -1

    return x, y

# %% [markdown]
# ### Funções de avaliação do problema:

# %%
class Problem:
  @staticmethod
  def f(x, y):
    '''
      x²+y²
    '''
    return x**2 + y**2

  @staticmethod
  def f_chromossome(chromossome):
    '''
      Retorna f(x,y) dado o cromossomo.
    '''
    x, y = Chromossome.get_fenotype(chromossome.get_genes())
    return Problem.f(x, y)

  @staticmethod
  def g(x, y):
    '''
      1/(x²+y²) + 1
      Usado como função de fitness (função de avaliação).
      Valor varia de 0 à 1 e quanto mais próximo de 1, melhor.
    '''
    return 1 / (1 + Problem.f(x, y))

  @staticmethod
  def g_chromossome(chromossome):
    '''
      Retorna fitness dado o cromossomo.
    '''
    x, y = Chromossome.get_fenotype(chromossome.get_genes())
    return Problem.g(x, y)

  @staticmethod
  def f_average(population):
    '''
      Retorna a média de f(x,y) dos cromossomos dada a população.
    '''
    avg = 0
    for chromossome in population:
      avg += Problem.f_chromossome(chromossome)
    avg /= len(population)
    return avg

  @staticmethod
  def g_average(population):
    '''
      Retorna a média de fitness dos cromossomos dada a população.
    '''
    avg = 0
    for chromossome in population:
      x, y = chromossome.get_fenotype(chromossome.get_genes())
      avg += Problem.g(x, y)
    avg /= len(population)
    return avg

# %% [markdown]
# ### Funções para operações com cromossomos:

# %%
class GeneticFunctions:
  @staticmethod
  def selection(population):
    '''
      Seleciona 2 cromossomos diferentes de forma aleatória.
    '''
    parent1 = random.choice(population)
    parent2 = random.choice(population)

    while parent1 is parent2:
      parent1 = random.choice(population)
      parent2 = random.choice(population)

    return parent1, parent2

  @staticmethod
  def crossover(population, parent1, parent2):
    '''
      Faz o cruzamento de 2 cromossomos, gerando 2 filhos e inserindo-os na população.
    '''
    crossover_point = random.randint(1, 9)

    parent1_genes = parent1.get_genes()
    parent2_genes = parent2.get_genes()

    child1_genes = BitSet(10)
    child2_genes = BitSet(10)

    for i in range(crossover_point):
      child1_genes.set(i, parent1_genes.get(i))
      child2_genes.set(i, parent2_genes.get(i))

    for i in range(crossover_point, 10):
      child1_genes.set(i, parent2_genes.get(i))
      child2_genes.set(i, parent1_genes.get(i))

    child1 = Chromossome()
    child1.set_genes(child1_genes)

    child2 = Chromossome()
    child2.set_genes(child2_genes)

    population.append(child1)
    population.append(child2)

    return crossover_point
      
  @staticmethod
  def mutation(population, mutation_prob):
    '''
      Gera mutação em 1 cromossomo aleatório da população dada a probabilidade de mutação.
    '''
    prob = random.uniform(0, 1)

    if prob < mutation_prob:
      target = random.choice(population)

      mutation_point = random.randint(0, 9)

      genes = target.get_genes()
      genes.flip(mutation_point)

      return True, mutation_point
    return False, None

  @staticmethod
  def elitism(population):
    '''
      Remove 2 dos piores cromossomos da população.
    '''
    for _ in range(2):
      worst_individual = GeneticFunctions.find_worst_chromossome(population)
      population.remove(worst_individual)
      
    return worst_individual

  @staticmethod
  def find_best_chromossome(population):
    '''
      Retorna o melhor cromossomo dada a população.
    '''
    best_chromossome = None

    for chromossome in population:
      score = Problem.g_chromossome(chromossome)

      if best_chromossome is None or score > Problem.g_chromossome(best_chromossome):
        best_chromossome = chromossome

    return best_chromossome

  @staticmethod
  def find_worst_chromossome(population):
    '''
      Retorna o pior cromossomo dada a população.
    '''
    worst_chromossome = None

    for chromossome in population:
      score = Problem.g_chromossome(chromossome)

      if worst_chromossome is None or score < Problem.g_chromossome(worst_chromossome):
        worst_chromossome = chromossome

    return worst_chromossome

# %% [markdown]
# ### Execução:

# %%
def executar(tam_populacao, n_geracoes, prob_mutacao):
  populacao = []
  for _ in range(tam_populacao):
    populacao.append(Chromossome())

  pontuacoes = []
  pontuacao_inicial = Problem.g_average(populacao)
  pontuacoes.append(pontuacao_inicial)

  medias_f = []
  media_f_inicial = Problem.f_average(populacao)
  medias_f.append(media_f_inicial)

  for geracao in range(n_geracoes):
    pai1, pai2 = GeneticFunctions.selection(populacao)

    pos_crossover = GeneticFunctions.crossover(populacao, pai1, pai2)
    teve_mutacao, pos_mutacao = GeneticFunctions.mutation(populacao, prob_mutacao)
    pior_cromossomo = GeneticFunctions.elitism(populacao)
   
    pontuacao = Problem.g_average(populacao)
    pontuacoes.append(pontuacao)

    media_f = Problem.f_average(populacao)
    medias_f.append(media_f)

  melhor_cromossomo = GeneticFunctions.find_best_chromossome(populacao)
  
  return melhor_cromossomo, pontuacoes, medias_f

def executar_com_prints(tam_populacao, n_geracoes, prob_mutacao):
  populacao = []
  for _ in range(tam_populacao):
    populacao.append(Chromossome())

  print('População inicial:', populacao)

  pontuacoes = []
  pontuacao_inicial = Problem.g_average(populacao)
  pontuacoes.append(pontuacao_inicial)

  print('Pontuação inicial:', pontuacao_inicial)

  medias_f = []
  media_f_inicial = Problem.f_average(populacao)
  medias_f.append(media_f_inicial)

  print('Média de f(x,y) inicial:', media_f_inicial)

  for geracao in range(n_geracoes):
    print('Geração:', geracao)

    pai1, pai2 = GeneticFunctions.selection(populacao)
    print('\tSelecionados:', pai1, pai2)

    pos_crossover = GeneticFunctions.crossover(populacao, pai1, pai2)
    print('\tCrossover entre selecionados na posição:', pos_crossover)

    teve_mutacao, pos_mutacao = GeneticFunctions.mutation(populacao, prob_mutacao)
    print('\tTeve mutação? ', teve_mutacao)
    if(teve_mutacao):
      print('\t\tNa posição:', pos_mutacao)
    
    pior_cromossomo = GeneticFunctions.elitism(populacao)
    print('Foi eliminado o pior cromossomo:', pior_cromossomo, Problem.g_chromossome(pior_cromossomo))

    pontuacao = Problem.g_average(populacao)
    print(f'Pontuação da geração {geracao}:', pontuacao)

    media_f = Problem.f_average(populacao)
    medias_f.append(media_f)
    print(f'Média de f(x,y) da geração {geracao}:', media_f)

    pontuacoes.append(pontuacao)

  melhor_cromossomo = GeneticFunctions.find_best_chromossome(populacao)
  
  return melhor_cromossomo, pontuacoes, medias_f

melhor_cromossomo, pontuacoes, medias_f = executar_com_prints(
  tam_populacao=10,
  n_geracoes=50,
  prob_mutacao=0.05
)

print('Melhor cromossomo:', melhor_cromossomo, Problem.g_chromossome(melhor_cromossomo))
# Out:
# População inicial: [G = [00100 01011], F = [2, -5], G = [01010 01111], F = [5, -7], G = [00110 00000], F = [3, 0], G = [00101 01110], F = [-2, 7], G = [01100 00100], F = [6, 2], G = [01110 00010], F = [7, 1], G = [00010 01010], F = [1, 5], G = [01110 01100], F = [7, 6], G = [00101 01100], F = [-2, 6], G = [00001 00011], F = [0, -1]]
# Pontuação inicial: 0.07822384601410995
# Média de f(x,y) inicial: 40.7
# Geração: 0
# 	Selecionados: G = [00001 00011], F = [0, -1] G = [01100 00100], F = [6, 2]
# 	Crossover entre selecionados na posição: 8
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [01010 01111], F = [5, -7] 0.013333333333333334
# Pontuação da geração 0: 0.17790163502658046
# Média de f(x,y) da geração 0: 29.3
# Geração: 1
# 	Selecionados: G = [00100 01011], F = [2, -5] G = [00010 01010], F = [1, 5]
# 	Crossover entre selecionados na posição: 6
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [01110 00010], F = [7, 1] 0.0196078431372549
# Pontuação da geração 1: 0.18112603589804016
# Média de f(x,y) da geração 1: 24.5
# Geração: 2
# 	Selecionados: G = [00110 00000], F = [3, 0] G = [00001 00011], F = [0, -1]
# 	Crossover entre selecionados na posição: 8
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [01100 00100], F = [6, 2] 0.024390243902439025
# Pontuação da geração 2: 0.285604007555227
# Média de f(x,y) da geração 2: 17.0
# Geração: 3
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00110 00000], F = [3, 0]
# 	Crossover entre selecionados na posição: 8
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00100 01011], F = [2, -5] 0.03333333333333333
# Pontuação da geração 3: 0.3898316498316498
# Média de f(x,y) da geração 3: 11.0
# Geração: 4
# 	Selecionados: G = [00100 01010], F = [2, 5] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 7
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00010 01010], F = [1, 5] 0.037037037037037035
# Pontuação da geração 4: 0.4375565175565175
# Média de f(x,y) da geração 4: 7.6
# Geração: 5
# 	Selecionados: G = [00110 00000], F = [3, 0] G = [00110 00011], F = [3, -1]
# 	Crossover entre selecionados na posição: 3
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00100 01000], F = [2, 4] 0.047619047619047616
# Pontuação da geração 5: 0.4481818181818181
# Média de f(x,y) da geração 5: 4.9
# Geração: 6
# 	Selecionados: G = [00110 00000], F = [3, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 8
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00110 00011], F = [3, -1] 0.09090909090909091
# Pontuação da geração 6: 0.5399999999999999
# Média de f(x,y) da geração 6: 3.8
# Geração: 7
# 	Selecionados: G = [00110 00000], F = [3, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 3
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00110 00000], F = [3, 0] 0.1
# Pontuação da geração 7: 0.59
# Média de f(x,y) da geração 7: 2.5
# Geração: 8
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00110 00000], F = [3, 0]
# 	Crossover entre selecionados na posição: 3
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00110 00000], F = [3, 0] 0.1
# Pontuação da geração 8: 0.64
# Média de f(x,y) da geração 8: 1.2
# Geração: 9
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00101 00000], F = [-2, 0]
# 	Crossover entre selecionados na posição: 1
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00101 00000], F = [-2, 0] 0.2
# Pontuação da geração 9: 0.72
# Média de f(x,y) da geração 9: 0.8
# Geração: 10
# 	Selecionados: G = [00001 00010], F = [0, 1] G = [00101 00000], F = [-2, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00101 00000], F = [-2, 0] 0.2
# Pontuação da geração 10: 0.8
# Média de f(x,y) da geração 10: 0.4
# Geração: 11
# 	Selecionados: G = [00010 00000], F = [1, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00010], F = [0, 1] 0.5
# Pontuação da geração 11: 0.85
# Média de f(x,y) da geração 11: 0.3
# Geração: 12
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 6
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00010 00000], F = [1, 0] 0.5
# Pontuação da geração 12: 0.95
# Média de f(x,y) da geração 12: 0.1
# Geração: 13
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 13: 1.0
# Média de f(x,y) da geração 13: 0.0
# Geração: 14
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 1
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 14: 1.0
# Média de f(x,y) da geração 14: 0.0
# Geração: 15
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 8
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 15: 1.0
# Média de f(x,y) da geração 15: 0.0
# Geração: 16
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 9
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 16: 1.0
# Média de f(x,y) da geração 16: 0.0
# Geração: 17
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 1
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 17: 1.0
# Média de f(x,y) da geração 17: 0.0
# Geração: 18
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 3
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 18: 1.0
# Média de f(x,y) da geração 18: 0.0
# Geração: 19
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 7
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 19: 1.0
# Média de f(x,y) da geração 19: 0.0
# Geração: 20
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 8
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 20: 1.0
# Média de f(x,y) da geração 20: 0.0
# Geração: 21
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 21: 1.0
# Média de f(x,y) da geração 21: 0.0
# Geração: 22
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 22: 1.0
# Média de f(x,y) da geração 22: 0.0
# Geração: 23
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 2
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 23: 1.0
# Média de f(x,y) da geração 23: 0.0
# Geração: 24
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 24: 1.0
# Média de f(x,y) da geração 24: 0.0
# Geração: 25
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 2
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 25: 1.0
# Média de f(x,y) da geração 25: 0.0
# Geração: 26
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 2
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 26: 1.0
# Média de f(x,y) da geração 26: 0.0
# Geração: 27
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 27: 1.0
# Média de f(x,y) da geração 27: 0.0
# Geração: 28
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 8
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 28: 1.0
# Média de f(x,y) da geração 28: 0.0
# Geração: 29
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 29: 1.0
# Média de f(x,y) da geração 29: 0.0
# Geração: 30
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 30: 1.0
# Média de f(x,y) da geração 30: 0.0
# Geração: 31
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 9
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 31: 1.0
# Média de f(x,y) da geração 31: 0.0
# Geração: 32
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 9
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 32: 1.0
# Média de f(x,y) da geração 32: 0.0
# Geração: 33
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 33: 1.0
# Média de f(x,y) da geração 33: 0.0
# Geração: 34
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 4
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 34: 1.0
# Média de f(x,y) da geração 34: 0.0
# Geração: 35
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 2
# 	Teve mutação?  True
# 		Na posição: 2
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 35: 1.0
# Média de f(x,y) da geração 35: 0.0
# Geração: 36
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 6
# 	Teve mutação?  True
# 		Na posição: 5
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 36: 1.0
# Média de f(x,y) da geração 36: 0.0
# Geração: 37
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 7
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 37: 1.0
# Média de f(x,y) da geração 37: 0.0
# Geração: 38
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 2
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 38: 1.0
# Média de f(x,y) da geração 38: 0.0
# Geração: 39
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 9
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 39: 1.0
# Média de f(x,y) da geração 39: 0.0
# Geração: 40
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 5
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 40: 1.0
# Média de f(x,y) da geração 40: 0.0
# Geração: 41
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 4
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 41: 1.0
# Média de f(x,y) da geração 41: 0.0
# Geração: 42
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 2
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 42: 1.0
# Média de f(x,y) da geração 42: 0.0
# Geração: 43
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 4
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 43: 1.0
# Média de f(x,y) da geração 43: 0.0
# Geração: 44
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 8
# 	Teve mutação?  True
# 		Na posição: 6
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 44: 1.0
# Média de f(x,y) da geração 44: 0.0
# Geração: 45
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 8
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 45: 1.0
# Média de f(x,y) da geração 45: 0.0
# Geração: 46
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 3
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 46: 1.0
# Média de f(x,y) da geração 46: 0.0
# Geração: 47
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 4
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 47: 1.0
# Média de f(x,y) da geração 47: 0.0
# Geração: 48
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 3
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 48: 1.0
# Média de f(x,y) da geração 48: 0.0
# Geração: 49
# 	Selecionados: G = [00001 00000], F = [0, 0] G = [00001 00000], F = [0, 0]
# 	Crossover entre selecionados na posição: 6
# 	Teve mutação?  False
# Foi eliminado o pior cromossomo: G = [00001 00000], F = [0, 0] 1.0
# Pontuação da geração 49: 1.0
# Média de f(x,y) da geração 49: 0.0
# Melhor cromossomo: G = [00001 00000], F = [0, 0] 1.0

# %% [markdown]
# ### Plot do fitness por geração:

# %%
import matplotlib.pyplot as plt

plt.gca().set_xlabel('Geração')
plt.gca().set_ylabel('Fitness')
plt.gca().set_title('Fitness por Geração')
plt.plot(range(len(pontuacoes)), pontuacoes)
plt.show()

# %% [markdown]
# ### Plot da média de f(x,y) por geração:

# %%
plt.gca().set_xlabel('Geração')
plt.gca().set_ylabel('Media de f(x,y)')
plt.gca().set_title('Media de f(x,y) por Geração')
plt.plot(range(len(medias_f)), medias_f)
plt.show()
